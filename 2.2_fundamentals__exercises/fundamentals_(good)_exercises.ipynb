# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Good) Exercises</span></div>

# %% [markdown]
# # Exercise 1

# %%
name = input("What is your name?")
print(f"How you doin {name}!")
# Out:
# How you doin !

# %%
name = input("What is your name?")
age = input("What is your age?")
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is  and I am  years old.

# %%
pi = 3.141592653589793

str_start, str_end = "The value of pi to", "decimal places is:"
print(f"{str_start} 2 {str_end} {pi:.2f}")
print(f"{str_start} 3 {str_end} {pi:.3f}")
print(f"{str_start} 4 {str_end} {pi:.4f}")
# Out:
# The value of pi to 2 decimal places is: 3.14
# The value of pi to 3 decimal places is: 3.142
# The value of pi to 4 decimal places is: 3.1416

# %%
for pair in [('Apple', '0.99'), ('Banana', '0.59'), ('Orange', '1.29')]:
    print(f"{pair[0]:<10} ${pair[1]:>5}")
# Out:
# Apple      $ 0.99
# Banana     $ 0.59
# Orange     $ 1.29

# %% [markdown]
# # Exercise 2

# %%
def valid_score():
    while True:
        try:
            user_input = int(input("Enter the student's score: "))
            if user_input > 100 or user_input < 0:
                print("Enter a score between 0 and 100")
            else:
                return user_input
        except ValueError:
            print("Invalid input, enter an integer")

score = valid_score()

grade = ''
if score >= 70:
    grade = 'A' 
elif score >= 50: 
    grade = 'B'
elif score >= 35:
    grade = 'C'
else:
    grade = 'Fail'

print(f"The student's letter grade is: {grade}")
# Out:
# The student's letter grade is: B

# %% [markdown]
# # Exercise 3

# %%
def factorial(n):
    if n <= 0:
        return "Invalid input"
    elif n == 0:
        return 1
    else:
        result = 1
        for number in range(1, n+1):
            result *= number
        return result


print(factorial(5))   # Testing, expected output: 120
print(factorial(-1))  # Testing, expected output: Invalid input
# Out:
# 120
# Invalid input
