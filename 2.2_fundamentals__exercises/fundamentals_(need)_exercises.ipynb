# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Need) Exercises</span></div>

# %% [markdown]
# # Exercise 1
#
# 1. Interpreted Language
# 2. Indentation Based
# 3. Dynamic Variables
# 4.

# %% [markdown]
# # Exercise 2

# %%
import math

x, y = 3, 4
z = math.sqrt(x*2 + y**2)
print(x, y, z)
# Out:
# 3 4 4.69041575982343

# %% [markdown]
# # Exercise 3

# %% [markdown]
# |  # | Term | Description|
# |---|---|---|
# | 1 | Function | Code block that can be called to specific tasks |
# | 2 | Arguments | Parameters that are passed to functions |
# | 3 | Comments | Can be used to label or explain segments of code |
# | 4 | Identations | Used to scope and structure code |
# | 5 | Packages | Structures code for reusability and organization |
# | 6 | . | Used to access properties or methods of an object |
# | 7 | : | Designates code blocks, also list comprehension |
# | 8 | [] | List, can be used to store variables |
# | 9 | [[], []] | Nested list, a list that stores multiple lists |
# | 10 | {} | Dictionary, stores key-value pairs |

# %% [markdown]
# # Exercise 4

# %%
x1 = 5 / 2 # Simple division
x2 = 5 // 2 # Gets quotient after division
x3 = 5 % 2 # Gets remainder after division
